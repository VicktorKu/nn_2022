# %% [markdown]
# <a href="https://colab.research.google.com/github/VicktorKu/nn_2022/blob/main/Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HEADER

# %% [markdown]
# Виконав роботу студент групи кн-31/2 Кульквоець Віктор

# %% [markdown]
# Лабораторна робота номер 1

# %% [markdown]
# # Main

# %% [markdown]
# ## NumPy

# %%
import numpy as np
import random
a1 = np.array([1,2,3])
a2 = np.array([[1,2,3]])
a3 = np.array([[1], 
               [2], 
               [3], 
               [4]])
Matrix33 = np.array([
               [1,0,0], 
               [0,1,0], 
               [0,0,1]])
print(Matrix33)
print(a3)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]
# [[1]
#  [2]
#  [3]
#  [4]]

# %% [markdown]
# ## Scalar

# %%
x = np.array([2,3.0,3,4,7.5,6,7,8.2,11]) 
y = np.array([2,10,4,10,1,10,1,15,11]) 
x = np.reshape(x, (x.shape[0],1))
y = np.reshape(y, (y.shape[0],1))
print("x.shape: ", x.shape)
print("y.shape: ", x.shape)
# Out:
# x.shape:  (9, 1)
# y.shape:  (9, 1)

# %% [markdown]
# ## Vector

# %%
print("OR: ", a1.shape) 

v = np.reshape(a1, (a1.shape[0],1))

print("reshaped: ", v.shape)
# Out:
# OR:  (3,)
# reshaped:  (3, 1)

# %% [markdown]
# ## Matrix in a row

# %%
M2 = np.reshape(M1, (1,12))
display(M2)
print(M2.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Админ\Desktop\labs\Нейронка\nn_2022\lab1\Lab1.ipynb Cell 13' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/%D0%90%D0%B4%D0%BC%D0%B8%D0%BD/Desktop/labs/%D0%9D%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BA%D0%B0/nn_2022/lab1/Lab1.ipynb#ch0000012?line=0'>1</a> M2 = np.reshape(M1, (1,12))
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%90%D0%B4%D0%BC%D0%B8%D0%BD/Desktop/labs/%D0%9D%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BA%D0%B0/nn_2022/lab1/Lab1.ipynb#ch0000012?line=1'>2</a> display(M2)
#       <a href='vscode-notebook-cell:/c%3A/Users/%D0%90%D0%B4%D0%BC%D0%B8%D0%BD/Desktop/labs/%D0%9D%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BA%D0%B0/nn_2022/lab1/Lab1.ipynb#ch0000012?line=2'>3</a> print(M2.shape)
#
# NameError: name 'M1' is not defined

# %% [markdown]
# ## Random array

# %%
n = 4
mas =np.random.randn (n,4) 
mas
# Out:
# array([[ 0.89558157, -0.28872093,  1.38044066,  0.82102483],
#        [-0.8944254 ,  0.35996625, -0.93369921, -0.5413141 ],
#        [-2.00854264, -1.3983906 , -1.27188779, -2.4732608 ],
#        [-1.14863783, -1.50909237,  0.52122768, -0.07927028]])

# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
np.random.seed(11) 
M4 = np.random.randn(10,10)
M4
# Out:
# array([[ 1.74945474, -0.286073  , -0.48456513, -2.65331856, -0.00828463,
#         -0.31963136, -0.53662936,  0.31540267,  0.42105072, -1.06560298],
#        [-0.88623967, -0.47573349,  0.68968231,  0.56119218, -1.30554851,
#         -1.11947526,  0.73683739,  1.57463407, -0.03107509, -0.68344663],
#        [ 1.0956297 , -0.30957664,  0.72575222,  1.54907163,  0.63007982,
#          0.07349324,  0.73227135, -0.64257539, -0.17809318, -0.57395456],
#        [-0.20437532, -0.4864951 , -0.18577532, -0.38053642,  0.08897764,
#          0.06367166,  0.29634711,  1.40277112, -1.54686257,  1.29561858],
#        [-0.23725045, -1.23234621, -0.17241977,  0.09183837,  1.06755846,
#         -1.06163445,  0.21734821,  0.1178195 , -1.68411089, -1.18575527],
#        [ 0.60010201,  0.69556726,  1.08771086,  0.53382172,  0.39521201,
#          0.12286753,  1.20910164, -0.8430661 , -0.14189358,  0.38535414],
#        [-1.57749431,  1.31094364, -0.79286501, -0.07174941,  2.15667443,
# ...

# %%
df = pd.DataFrame(M4)
df
# Out:
#           0         1         2  ...         7         8         9
# 0  1.749455 -0.286073 -0.484565  ...  0.315403  0.421051 -1.065603
# 1 -0.886240 -0.475733  0.689682  ...  1.574634 -0.031075 -0.683447
# 2  1.095630 -0.309577  0.725752  ... -0.642575 -0.178093 -0.573955
# 3 -0.204375 -0.486495 -0.185775  ...  1.402771 -1.546863  1.295619
# 4 -0.237250 -1.232346 -0.172420  ...  0.117820 -1.684111 -1.185755
# 5  0.600102  0.695567  1.087711  ... -0.843066 -0.141894  0.385354
# 6 -1.577494  1.310944 -0.792865  ...  1.561704 -1.080194 -0.432058
# 7  0.516084  0.455393  0.593686  ... -0.682802 -0.713560 -1.908290
# 8  0.687312 -1.823010  0.879114  ...  0.830310 -0.863353 -0.130541
# 9 -0.523088 -0.251277  1.291275  ... -1.264074  1.114870  0.434777
#
# [10 rows x 10 columns]

# %% [markdown]
# ## head

# %%
df.head(n=5)
# Out:
#           0         1         2  ...         7         8         9
# 0  1.749455 -0.286073 -0.484565  ...  0.315403  0.421051 -1.065603
# 1 -0.886240 -0.475733  0.689682  ...  1.574634 -0.031075 -0.683447
# 2  1.095630 -0.309577  0.725752  ... -0.642575 -0.178093 -0.573955
# 3 -0.204375 -0.486495 -0.185775  ...  1.402771 -1.546863  1.295619
# 4 -0.237250 -1.232346 -0.172420  ...  0.117820 -1.684111 -1.185755
#
# [5 rows x 10 columns]

# %% [markdown]
# ## describe

# %%
df.describe()
# Out:
#                0          1          2  ...          7          8          9
# count  10.000000  10.000000  10.000000  ...  10.000000  10.000000  10.000000
# mean    0.122014  -0.240261   0.363159  ...   0.237012  -0.470322  -0.386390
# std     0.992000   0.905439   0.713911  ...   1.070563   0.876317   0.925354
# min    -1.577494  -1.823010  -0.792865  ...  -1.264074  -1.684111  -1.908290
# 25%    -0.451628  -0.483805  -0.182436  ...  -0.672745  -1.025983  -0.970064
# 50%     0.155854  -0.297825   0.641684  ...   0.216611  -0.445827  -0.503006
# 75%     0.665510   0.278725   0.840773  ...   1.259656  -0.058780   0.256380
# max     1.749455   1.310944   1.291275  ...   1.574634   1.114870   1.295619
#
# [8 rows x 10 columns]

# %% [markdown]
# ## iloc

# %%
df.iloc[4]
# Out:
# 0   -0.237250
# 1   -1.232346
# 2   -0.172420
# 3    0.091838
# 4    1.067558
# 5   -1.061634
# 6    0.217348
# 7    0.117820
# 8   -1.684111
# 9   -1.185755
# Name: 4, dtype: float64

# %% [markdown]
# ## loc

# %%
df.loc[0,2]
# Out:
# -0.4845651322211443

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
y = np.array([1, 2, 0])
yhat = np.random.random_integers(2,3,3)
x = np.array([5, 2, 4])
plt.plot(x, y, color="red", label="2")
plt.plot(x, yhat, color="green", label="2")
plt.plot(y, yhat, color="blue", label="5")
plt.scatter(x, y, color="black", label="4")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: This function is deprecated. Please call randint(2, 3 + 1) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # FOOTOR

# %% [markdown]
# ## Висновки

# %% [markdown]
# Висновки: на даній лабораторній роботі ми вивчили велику кіллькість роботи з python та colaboratory.
